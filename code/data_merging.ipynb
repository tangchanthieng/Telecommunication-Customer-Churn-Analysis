# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_demographics = pd.read_excel("Telco_customer_churn_demographics.xlsx")
df_location = pd.read_excel("Telco_customer_churn_location.xlsx")
df_services = pd.read_excel("Telco_customer_churn_services.xlsx")
df_status = pd.read_excel("Telco_customer_churn_status.xlsx")

# %%
def safe_merge(df_left, df_right):
    common_cols = set(df_left.columns) & set(df_right.columns) - {'Customer ID'}
    df_right_clean = df_right.drop(columns=common_cols)
    return df_left.merge(df_right_clean, on='Customer ID', how='outer')

df_merged = safe_merge(df_demographics, df_location)
df_merged = safe_merge(df_merged, df_services)
df_merged = safe_merge(df_merged, df_status)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 55 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Count                              7043 non-null   int64
#  2   Gender                             7043 non-null   object
#  3   Age                                7043 non-null   int64
#  4   Under 30                           7043 non-null   object
#  5   Senior Citizen                     7043 non-null   object
#  6   Married                            7043 non-null   object
#  7   Dependents                         7043 non-null   object
#  8   Number of Dependents               7043 non-null   int64
#  9   Location ID                        7043 non-null   object
#  10  Country                            7043 non-null   object
#  11  State                              7043 non-null   object
#  12  City                               7043 non-null   object
#  13  Zip Code                           7043 non-null   int64
#  14  Lat Long                           7043 non-null   object
#  15  Latitude                           7043 non-null   float64
#  16  Longitude                          7043 non-null   float64
#  17  Service ID                         7043 non-null   object
#  18  Quarter                            7043 non-null   object
#  19  Referred a Friend                  7043 non-null   object
#  20  Number of Referrals                7043 non-null   int64
#  21  Tenure in Months                   7043 non-null   int64
#  22  Offer                              3166 non-null   object
#  23  Phone Service                      7043 non-null   object
#  24  Avg Monthly Long Distance Charges  7043 non-null   float64
#  25  Multiple Lines                     7043 non-null   object
#  26  Internet Service                   7043 non-null   object
#  27  Internet Type                      5517 non-null   object
#  28  Avg Monthly GB Download            7043 non-null   int64
#  29  Online Security                    7043 non-null   object
#  30  Online Backup                      7043 non-null   object
#  31  Device Protection Plan             7043 non-null   object
#  32  Premium Tech Support               7043 non-null   object
#  33  Streaming TV                       7043 non-null   object
#  34  Streaming Movies                   7043 non-null   object
#  35  Streaming Music                    7043 non-null   object
#  36  Unlimited Data                     7043 non-null   object
#  37  Contract                           7043 non-null   object
#  38  Paperless Billing                  7043 non-null   object
#  39  Payment Method                     7043 non-null   object
#  40  Monthly Charge                     7043 non-null   float64
#  41  Total Charges                      7043 non-null   float64
#  42  Total Refunds                      7043 non-null   float64
#  43  Total Extra Data Charges           7043 non-null   int64
#  44  Total Long Distance Charges        7043 non-null   float64
#  45  Total Revenue                      7043 non-null   float64
#  46  Status ID                          7043 non-null   object
#  47  Satisfaction Score                 7043 non-null   int64
#  48  Customer Status                    7043 non-null   object
#  49  Churn Label                        7043 non-null   object
#  50  Churn Value                        7043 non-null   int64
#  51  Churn Score                        7043 non-null   int64
#  52  CLTV                               7043 non-null   int64
#  53  Churn Category                     1869 non-null   object
#  54  Churn Reason                       1869 non-null   object
# dtypes: float64(8), int64(12), object(35)
# memory usage: 3.0+ MB

# %%
df_merged.describe(include='all')
# Out:
#        Customer ID   Count Gender          Age Under 30 Senior Citizen  \
# count         7043  7043.0   7043  7043.000000     7043           7043
# unique        7043     NaN      2          NaN        2              2
# top     9995-HOTOH     NaN   Male          NaN       No             No
# freq             1     NaN   3555          NaN     5642           5901
# mean           NaN     1.0    NaN    46.509726      NaN            NaN
# std            NaN     0.0    NaN    16.750352      NaN            NaN
# min            NaN     1.0    NaN    19.000000      NaN            NaN
# 25%            NaN     1.0    NaN    32.000000      NaN            NaN
# 50%            NaN     1.0    NaN    46.000000      NaN            NaN
# 75%            NaN     1.0    NaN    60.000000      NaN            NaN
# max            NaN     1.0    NaN    80.000000      NaN            NaN
#
#        Married Dependents  Number of Dependents Location ID  ...  \
# count     7043       7043           7043.000000        7043  ...
# unique       2          2                   NaN        7043  ...
# top         No         No                   NaN  CRAMQJ1493  ...
# freq      3641       5416                   NaN           1  ...
# mean       NaN        NaN              0.468692         NaN  ...
# std        NaN        NaN              0.962802         NaN  ...
# min        NaN        NaN              0.000000         NaN  ...
# 25%        NaN        NaN              0.000000         NaN  ...
# 50%        NaN        NaN              0.000000         NaN  ...
# 75%        NaN        NaN              0.000000         NaN  ...
# max        NaN        NaN              9.000000         NaN  ...
#
#        Total Revenue   Status ID Satisfaction Score  Customer Status  \
# count    7043.000000        7043        7043.000000             7043
# unique           NaN        7043                NaN                3
# top              NaN  UKMXFW1552                NaN           Stayed
# freq             NaN           1                NaN             4720
# mean     3034.379056         NaN           3.244924              NaN
# std      2865.204542         NaN           1.201657              NaN
# min        21.360000         NaN           1.000000              NaN
# 25%       605.610000         NaN           3.000000              NaN
# 50%      2108.640000         NaN           3.000000              NaN
# 75%      4801.145000         NaN           4.000000              NaN
# max     11979.340000         NaN           5.000000              NaN
#
#        Churn Label  Churn Value  Churn Score         CLTV Churn Category  \
# count         7043  7043.000000  7043.000000  7043.000000           1869
# unique           2          NaN          NaN          NaN              5
# top             No          NaN          NaN          NaN     Competitor
# freq          5174          NaN          NaN          NaN            841
# mean           NaN     0.265370    58.505040  4400.295755            NaN
# std            NaN     0.441561    21.170031  1183.057152            NaN
# min            NaN     0.000000     5.000000  2003.000000            NaN
# 25%            NaN     0.000000    40.000000  3469.000000            NaN
# 50%            NaN     0.000000    61.000000  4527.000000            NaN
# 75%            NaN     1.000000    75.500000  5380.500000            NaN
# max            NaN     1.000000    96.000000  6500.000000            NaN
#
#                          Churn Reason
# count                            1869
# unique                             20
# top     Competitor had better devices
# freq                              313
# mean                              NaN
# std                               NaN
# min                               NaN
# 25%                               NaN
# 50%                               NaN
# 75%                               NaN
# max                               NaN
#
# [11 rows x 55 columns]

# %%
df_merged.isnull().sum()
# Out:
# Customer ID                             0
# Count                                   0
# Gender                                  0
# Age                                     0
# Under 30                                0
# Senior Citizen                          0
# Married                                 0
# Dependents                              0
# Number of Dependents                    0
# Location ID                             0
# Country                                 0
# State                                   0
# City                                    0
# Zip Code                                0
# Lat Long                                0
# Latitude                                0
# Longitude                               0
# Service ID                              0
# Quarter                                 0
# Referred a Friend                       0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3877
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                          0
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download                 0
# Online Security                         0
# Online Backup                           0
# Device Protection Plan                  0
# Premium Tech Support                    0
# Streaming TV                            0
# Streaming Movies                        0
# Streaming Music                         0
# Unlimited Data                          0
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charge                          0
# Total Charges                           0
# Total Refunds                           0
# Total Extra Data Charges                0
# Total Long Distance Charges             0
# Total Revenue                           0
# Status ID                               0
# Satisfaction Score                      0
# Customer Status                         0
# Churn Label                             0
# Churn Value                             0
# Churn Score                             0
# CLTV                                    0
# Churn Category                       5174
# Churn Reason                         5174
# dtype: int64

# %%
df_merged['Offer'].unique()
# Out:
# array([nan, 'Offer E', 'Offer D', 'Offer A', 'Offer B', 'Offer C'],
#       dtype=object)

# %%
df_merged['Internet Type'].unique()
# Out:
# array(['Cable', 'Fiber Optic', 'DSL', nan], dtype=object)

# %%
df_merged['Churn Category'].unique()
# Out:
# array([nan, 'Competitor', 'Dissatisfaction', 'Other', 'Price', 'Attitude'],
#       dtype=object)

# %%
df_merged['Churn Reason'].unique()
# Out:
# array([nan, 'Competitor had better devices', 'Product dissatisfaction',
#        'Network reliability', 'Limited range of services',
#        'Competitor made better offer', "Don't know",
#        'Long distance charges', 'Attitude of service provider',
#        'Attitude of support person',
#        'Competitor offered higher download speeds',
#        'Competitor offered more data',
#        'Lack of affordable download/upload speed', 'Deceased', 'Moved',
#        'Service dissatisfaction', 'Price too high',
#        'Lack of self-service on Website',
#        'Poor expertise of online support', 'Extra data charges',
#        'Poor expertise of phone support'], dtype=object)

# %%
df_merged.duplicated().sum()
# Out:
# np.int64(0)
